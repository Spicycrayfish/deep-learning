# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
words = Counter(int_words)

total_num = len(int_words)

word_freq = {word : words[word] / total_num for word in set(int_words)}

word_prob = {word : (1 - np.sqrt(threshold / word_freq[word])) for word in words}

train_words = [word for word in int_words if word_freq[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = random.randint(1, window_size+1)
    
    start_index = idx - R if idx > R else 0
    stop_index = idx + R + 1
    
    target_words = set(words[start_index : idx] + words[idx+1 : stop_index])
    return target_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
            # why [batch_x]*len(batch_y) ?
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  250
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 7.9790 0.6368 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 7.3336 0.6457 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.5942 0.4857 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 6.1466 0.4962 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.8627 0.5467 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6193 0.6325 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4567 0.6261 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.2937 0.6216 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.2088 0.6220 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.0261 0.5885 sec/batch
# Nearest to was: did, integrated, diaries, center, united, some, casement, spent,
# Nearest to to: been, become, player, did, celebrate, was, flat, melito,
# Nearest to will: chase, trajectory, islands, pick, won, amount, cover, eccentric,
# Nearest to that: godfrey, came, speaking, bovidae, timeline, queen, atb, website,
# Nearest to b: write, subject, commemorate, dunbar, melville, mistaken, flatly, dysfunction,
# Nearest to system: ce, sentiments, reflecting, unlawful, detainees, connery, died, bastia,
# Nearest to many: deformed, inhomogeneities, maps, specimen, allows, affairs, throne, bring,
# Nearest to d: fraenkel, axiom, carcinogenic, favorite, mould, polish, lots, subtitled,
# Nearest to event: horst, hiv, territory, tippi, sham, battalions, histories, particular,
# Nearest to older: protected, harry, airs, sultans, move, gutrune, robert, closed,
# Nearest to magazine: engagements, domestic, lot, landowners, observations, law, starbuck, grandmother,
# Nearest to writers: existed, returning, ina, carlos, suicide, it, abelson, rhombicuboctahedron,
# Nearest to smith: albeit, monday, speculators, kari, colder, bs, tess, joliot,
# Nearest to running: manages, aggression, synchronize, apparently, victims, invalid, visigoths, detached,
# Nearest to freedom: oas, vivant, widely, became, rn, sima, computing, exclusively,
# Nearest to powers: minix, assigned, word, rendered, pieces, pence, she, regulation,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 4.9626 0.6504 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.0490 0.6232 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.0160 0.6652 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 4.9511 0.6230 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 4.9251 0.6232 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.9210 0.5918 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.9120 0.6340 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.8469 0.5419 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.8824 0.5434 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.8553 0.6137 sec/batch
# Nearest to was: integrated, did, diaries, center, united, consolidated, lou, spent,
# Nearest to to: celebrate, professionals, flat, been, incursions, become, permanently, titled,
# Nearest to will: trajectory, chase, eccentric, beer, pick, animism, amount, nightmare,
# Nearest to that: godfrey, came, timeline, speaking, annexation, bovidae, firework, atb,
# Nearest to b: commemorate, cockpit, dunbar, dysfunction, subject, mistaken, flatly, write,
# Nearest to system: ce, sentiments, reflecting, detainees, unlawful, rod, connery, slaves,
# Nearest to many: maps, allows, deformed, idf, inhomogeneities, specimen, ferment, customs,
# Nearest to d: fraenkel, axiom, carcinogenic, favorite, mould, lots, laureate, subtitled,
# Nearest to event: hiv, horst, disturbance, battalions, sham, tippi, ignition, histories,
# Nearest to older: protected, harry, airs, sultans, comrades, gutrune, closed, carbon,
# Nearest to magazine: engagements, landowners, domestic, pakistan, starbuck, lot, catalog, bert,
# Nearest to writers: existed, ina, returning, carlos, barcelona, rhombicuboctahedron, abelson, habib,
# Nearest to smith: albeit, monday, speculators, colder, raiders, concentrated, tn, bs,
# Nearest to running: manages, aggression, synchronize, invalid, mycenaean, detached, catholics, visigoths,
# Nearest to freedom: rn, oas, vivant, sima, hometown, corrupt, appendix, traverse,
# Nearest to powers: hosts, rendered, minix, chiefs, ramirez, assigned, voices, azteca,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.7911 0.6406 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8638 0.6294 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8496 0.6137 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.6698 0.6342 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7686 0.5848 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7856 0.6059 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7549 0.6121 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7809 0.5996 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7178 0.4844 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7182 0.5091 sec/batch
# Nearest to was: did, integrated, blanc, diaries, center, ricardian, lou, spent,
# Nearest to to: celebrate, professionals, incursions, flat, evolves, permanently, player, melito,
# Nearest to will: trajectory, chase, eccentric, beer, animism, nightmare, adverbs, amount,
# Nearest to that: godfrey, annexation, firework, raging, liberals, turf, came, condoleezza,
# Nearest to b: cockpit, subject, commemorate, dysfunction, melville, dunbar, flamingo, detour,
# Nearest to system: reflecting, detainees, ce, sentiments, unlawful, rod, connery, slaves,
# Nearest to many: allows, deformed, ferment, specimen, idf, maps, inhomogeneities, sculpted,
# Nearest to d: fraenkel, lots, axiom, mould, carcinogenic, favorite, subtitled, witted,
# Nearest to event: hiv, horst, disturbance, battalions, ignition, tippi, sham, dulles,
# Nearest to older: protected, harry, airs, sultans, comrades, gutrune, dumped, theorist,
# Nearest to magazine: engagements, landowners, starbuck, domestic, outlet, catalog, pakistan, lot,
# Nearest to writers: existed, ina, returning, barcelona, abelson, carlos, rhombicuboctahedron, habib,
# Nearest to smith: albeit, bs, monday, speculators, octaves, colder, kari, raiders,
# Nearest to running: manages, aggression, synchronize, detached, invalid, brandt, mycenaean, inspection,
# Nearest to freedom: rn, oas, corrupt, vivant, sima, hometown, grievous, appendix,
# Nearest to powers: hosts, rendered, minix, watering, chiefs, pseudepigraphical, voices, needing,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.6536 0.5598 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.6670 0.6206 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6806 0.6252 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7128 0.6391 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7096 0.6112 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6636 0.5334 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6777 0.4628 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6360 0.4636 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6826 0.4657 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6053 0.4619 sec/batch
# Nearest to was: did, integrated, blanc, ricardian, lou, spent, center, diaries,
# Nearest to to: celebrate, professionals, evolves, flat, permanently, incursions, homogeneous, hogs,
# Nearest to will: trajectory, chase, eccentric, beer, nightmare, animism, adverbs, strikingly,
# Nearest to that: godfrey, annexation, firework, raging, atb, liberals, condoleezza, rivalling,
# Nearest to b: cockpit, subject, detour, melville, dysfunction, oaks, commemorate, dunbar,
# Nearest to system: detainees, reflecting, sentiments, unlawful, ce, connery, repubblica, rod,
# Nearest to many: deformed, inhomogeneities, allows, ferment, idf, specimen, maps, sculpted,
# Nearest to d: fraenkel, axiom, lots, carcinogenic, mould, subtitled, favorite, secures,
# Nearest to event: hiv, horst, disturbance, battalions, ignition, histories, quark, tippi,
# Nearest to older: protected, harry, airs, sultans, giedi, theorist, comrades, dumped,
# Nearest to magazine: engagements, landowners, domestic, starbuck, hawthorne, outlet, catalog, bioengineering,
# Nearest to writers: ina, existed, returning, abelson, gagged, habib, chervil, barcelona,
# Nearest to smith: albeit, bs, speculators, monday, octaves, plump, kari, colder,
# Nearest to running: manages, synchronize, aggression, silverstone, detached, mycenaean, invalid, inspection,
# Nearest to freedom: rn, oas, corrupt, vivant, sima, grievous, appendix, verbatim,
# Nearest to powers: watering, hosts, rendered, chiefs, minix, pence, pseudepigraphical, needing,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.4733 0.5094 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6694 0.6079 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6455 0.5755 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.5898 0.6129 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.5882 0.6182 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6292 0.6100 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.5862 0.4823 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.6109 0.4930 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.6091 0.6095 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.6318 0.6136 sec/batch
# Nearest to was: did, blanc, ricardian, integrated, spent, lou, diaries, praetor,
# Nearest to to: celebrate, professionals, evolves, organically, incursions, flat, homogeneous, permanently,
# Nearest to will: trajectory, chase, eccentric, beer, animism, adverbs, amount, nightmare,
# Nearest to that: godfrey, atb, raging, annexation, firework, condoleezza, arteries, turf,
# Nearest to b: detour, melville, cockpit, subject, oaks, dysfunction, houghton, drc,
# Nearest to system: detainees, reflecting, connery, sentiments, unlawful, repubblica, ce, rod,
# Nearest to many: ferment, allows, deformed, inhomogeneities, recognize, teil, idf, sculpted,
# Nearest to d: fraenkel, subtitled, axiom, favorite, carcinogenic, lots, mould, secures,
# Nearest to event: hiv, horst, disturbance, battalions, ignition, diminishes, tippi, advantageous,
# Nearest to older: protected, harry, airs, sultans, giedi, underlining, comrades, dumped,
# Nearest to magazine: engagements, landowners, domestic, starbuck, hawthorne, catalog, outlet, apr,
# Nearest to writers: ina, existed, gagged, chervil, returning, habib, abelson, nonzero,
# Nearest to smith: albeit, speculators, bs, monday, kari, plump, raiders, tn,
# Nearest to running: manages, synchronize, aggression, algal, brandt, silverstone, detached, mycenaean,
# Nearest to freedom: oas, rn, corrupt, sima, vivant, verbatim, grievous, appendix,
# Nearest to powers: watering, rendered, pence, hosts, pseudepigraphical, chiefs, minix, mccormick,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.6430 0.6243 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.6017 0.6132 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.6074 0.6025 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.6105 0.4892 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.5840 0.5968 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.5810 0.6364 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.5550 0.6294 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.5844 0.4522 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.6029 0.4429 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.5997 0.4452 sec/batch
# Nearest to was: did, ricardian, blanc, integrated, spent, withdrawn, praetor, lou,
# Nearest to to: melito, professionals, incursions, hogs, evolves, celebrate, heldenplatz, maui,
# Nearest to will: trajectory, chase, eccentric, beer, pick, amount, adverbs, menagerie,
# Nearest to that: condoleezza, atb, godfrey, raging, firework, annexation, obstinately, liberals,
# Nearest to b: detour, cockpit, melville, oaks, houghton, subject, flatly, dysfunction,
# Nearest to system: detainees, reflecting, connery, sentiments, unlawful, repubblica, chola, flavours,
# Nearest to many: ferment, inhomogeneities, allows, deformed, recognize, keto, fares, catv,
# Nearest to d: fraenkel, subtitled, axiom, favorite, carcinogenic, secures, typhon, lots,
# Nearest to event: hiv, horst, disturbance, sham, battalions, diminishes, tippi, ignition,
# Nearest to older: protected, harry, airs, underlining, sultans, dumped, theorist, giedi,
# Nearest to magazine: engagements, landowners, hawthorne, domestic, apr, starbuck, catalog, outlet,
# Nearest to writers: ina, gagged, existed, habib, chervil, nonzero, carlos, returning,
# Nearest to smith: speculators, albeit, bs, plump, monday, kari, raiders, tn,
# Nearest to running: manages, synchronize, brandt, algal, silverstone, aggression, detached, mycenaean,
# Nearest to freedom: rn, oas, corrupt, vivant, sima, verbatim, appendix, sonet,
# Nearest to powers: watering, pence, pseudepigraphical, chiefs, rendered, hosts, mccormick, needing,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.5227 0.4451 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.5678 0.4411 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.5623 0.4405 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.5206 0.4407 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.5504 0.4426 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.5835 0.4404 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.5541 0.4426 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.5428 0.4421 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.5566 0.4475 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.5671 33.8085 sec/batch
# Nearest to was: did, ricardian, blanc, spent, eradicated, withdrawn, integrated, lou,
# Nearest to to: melito, evolves, hogs, incursions, heldenplatz, professionals, maui, permanently,
# Nearest to will: trajectory, chase, menagerie, beer, eccentric, pick, amount, nightmare,
# Nearest to that: atb, condoleezza, godfrey, firework, annexation, raging, liberals, arteries,
# Nearest to b: cockpit, detour, houghton, melville, michael, dunbar, oaks, flatly,
# Nearest to system: detainees, reflecting, sentiments, connery, chola, unlawful, flavours, repubblica,
# Nearest to many: ferment, inhomogeneities, deformed, recognize, allows, catv, helmeted, keto,
# Nearest to d: fraenkel, subtitled, axiom, dramatist, favorite, typhon, secures, laureate,
# Nearest to event: horst, disturbance, hiv, battalions, sham, diminishes, ignition, tippi,
# Nearest to older: protected, harry, airs, underlining, sultans, dumped, giedi, theorist,
# Nearest to magazine: engagements, landowners, hawthorne, starbuck, apr, catalog, domestic, bioengineering,
# Nearest to writers: ina, chervil, existed, gagged, habib, nonzero, rhombicuboctahedron, carlos,
# Nearest to smith: speculators, monday, plump, bs, kari, albeit, raiders, ellis,
# Nearest to running: manages, synchronize, brandt, silverstone, algal, detached, aggression, perro,
# Nearest to freedom: oas, rn, vivant, corrupt, sima, verbatim, sonet, cowardice,
# Nearest to powers: watering, pence, pseudepigraphical, chiefs, rendered, mccormick, hosts, needing,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.5176 74.6362 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.4490 129.7392 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.5464 144.1183 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.5082 842.3780 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.5068 0.4905 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.5477 0.5411 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.5458 0.4769 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.5161 0.5274 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.5091 0.5359 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.5283 0.5203 sec/batch
# Nearest to was: did, ricardian, blanc, spent, wrote, withdrawn, lou, praetor,
# Nearest to to: melito, heldenplatz, svalbard, hogs, permanently, organically, professionals, celebrate,
# Nearest to will: trajectory, chase, menagerie, pnc, beer, nightmare, pick, buford,
# Nearest to that: condoleezza, atb, raging, godfrey, firework, annexation, liberals, bovidae,
# Nearest to b: melville, cockpit, detour, dunbar, houghton, oaks, canisters, drc,
# Nearest to system: detainees, reflecting, connery, chola, sentiments, unlawful, flavours, chirality,
# Nearest to many: ferment, recognize, deformed, inhomogeneities, catv, keto, figuring, kuna,
# Nearest to d: fraenkel, subtitled, favorite, dramatist, typhon, axiom, parastatal, jettison,
# Nearest to event: disturbance, horst, hiv, battalions, sham, diminishes, ignition, tippi,
# Nearest to older: protected, harry, airs, underlining, sultans, theorist, dumped, giedi,
# Nearest to magazine: engagements, landowners, starbuck, hawthorne, apr, domestic, catalog, bioengineering,
# Nearest to writers: chervil, ina, gagged, zamora, habib, rhombicuboctahedron, existed, nonzero,
# Nearest to smith: speculators, monday, bs, plump, kari, albeit, raiders, tale,
# Nearest to running: manages, synchronize, silverstone, algal, brandt, detached, aggression, perro,
# Nearest to freedom: vivant, oas, rn, corrupt, sima, sonet, verbatim, almirante,
# Nearest to powers: pseudepigraphical, watering, pence, chiefs, hosts, mccormick, rendered, goldsmiths,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.5349 0.5155 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.4596 0.4900 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.5152 0.4671 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.5182 0.4619 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.4423 0.4563 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.4576 0.4702 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.5238 0.4830 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.4719 0.4349 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.5361 0.4935 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.5119 0.4832 sec/batch
# Nearest to was: did, ricardian, rinaldo, spent, praetor, blanc, refutations, wrote,
# Nearest to to: svalbard, heldenplatz, melito, hogs, evolves, organically, permanently, incursions,
# Nearest to will: trajectory, chase, menagerie, pnc, beer, eccentric, pick, nightmare,
# Nearest to that: atb, condoleezza, godfrey, firework, raging, lay, rivalling, problem,
# Nearest to b: melville, cockpit, dunbar, detour, simons, oaks, michael, qquad,
# Nearest to system: detainees, reflecting, connery, chola, unlawful, flavours, sentiments, repubblica,
# Nearest to many: ferment, recognize, inhomogeneities, catv, deformed, some, tact, flags,
# Nearest to d: fraenkel, dramatist, laureate, favorite, subtitled, typhon, secures, parastatal,
# Nearest to event: disturbance, hiv, horst, diminishes, battalions, sham, tippi, impregnated,
# Nearest to older: protected, harry, airs, underlining, sultans, theorist, dumped, giedi,
# Nearest to magazine: engagements, hawthorne, landowners, starbuck, katakana, apr, domestic, bluebeard,
# Nearest to writers: chervil, craggy, gagged, ina, habib, zamora, rhombicuboctahedron, nonzero,
# Nearest to smith: speculators, plump, monday, albeit, bs, kari, raiders, kuhn,
# Nearest to running: manages, synchronize, silverstone, brandt, algal, sneeze, aggression, perro,
# Nearest to freedom: vivant, corrupt, rn, oas, sonet, sima, verbatim, appendix,
# Nearest to powers: pseudepigraphical, watering, pence, chiefs, rendered, mccormick, hosts, azteca,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 4.4965 0.4501 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 4.4728 0.5125 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 4.4932 0.5036 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 4.3805 0.5441 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.5216 0.5412 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.4980 0.4479 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.5231 0.5214 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.4950 0.5025 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.5053 0.4431 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.5175 0.4487 sec/batch
# Nearest to was: did, ricardian, rinaldo, lou, spent, eradicated, praetor, withdrawn,
# Nearest to to: heldenplatz, svalbard, melito, permanently, incursions, organically, hogs, evolves,
# Nearest to will: trajectory, chase, menagerie, pnc, nightmare, beer, pick, eccentric,
# Nearest to that: atb, firework, raging, condoleezza, annexation, bovidae, rivalling, outsource,
# Nearest to b: melville, cockpit, oaks, qquad, detour, simons, dunbar, houghton,
# Nearest to system: detainees, reflecting, chola, connery, repubblica, unlawful, flavours, sentiments,
# Nearest to many: ferment, some, catv, inhomogeneities, deformed, earliest, visualize, recognize,
# Nearest to d: fraenkel, subtitled, favorite, dramatist, parastatal, typhon, axiom, jettison,
# Nearest to event: disturbance, horst, hiv, diminishes, battalions, sham, impregnated, ignition,
# Nearest to older: protected, harry, airs, underlining, sultans, theorist, giedi, sewn,
# Nearest to magazine: engagements, starbuck, hawthorne, apr, landowners, katakana, domestic, bluebeard,
# Nearest to writers: chervil, craggy, zamora, gagged, habib, rhombicuboctahedron, ina, therus,
# Nearest to smith: speculators, plump, bs, monday, raiders, kari, albeit, tale,
# Nearest to running: manages, synchronize, silverstone, algal, perro, brandt, sneeze, detached,
# Nearest to freedom: vivant, oas, corrupt, rn, sonet, sima, verbatim, cowardice,
# Nearest to powers: pseudepigraphical, watering, chiefs, pence, hosts, mccormick, rendered, wherever,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.5181 0.4737 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.4897 0.4627 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.4281 0.4601 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.4818 0.4454 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.5226 0.4435 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.4897 0.4400 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.4976 0.4405 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.4610 0.5003 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.4954 0.4675 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.4996 0.4684 sec/batch
# Nearest to was: did, ricardian, rinaldo, lou, praetor, spent, is, blanc,
# Nearest to to: heldenplatz, melito, svalbard, incursions, organically, hogs, maui, permanently,
# Nearest to will: trajectory, chase, menagerie, pnc, pick, nightmare, buford, slows,
# Nearest to that: atb, raging, firework, condoleezza, annexation, liberals, rivalling, lay,
# Nearest to b: oaks, melville, cockpit, simons, qquad, drc, flatly, detour,
# Nearest to system: detainees, reflecting, connery, chola, repubblica, sentiments, flavours, unlawful,
# Nearest to many: ferment, some, deformed, earliest, inhomogeneities, catv, recognize, tact,
# Nearest to d: fraenkel, subtitled, favorite, axiom, parastatal, dramatist, typhon, jettison,
# Nearest to event: disturbance, horst, hiv, diminishes, tippi, battalions, sham, sheepdog,
# Nearest to older: protected, harry, underlining, airs, theorist, sultans, sewn, arndt,
# Nearest to magazine: engagements, starbuck, bluebeard, apr, domestic, inflating, prize, hawthorne,
# Nearest to writers: chervil, craggy, bishvat, gagged, therus, rhombicuboctahedron, zamora, ina,
# Nearest to smith: speculators, plump, bs, monday, albeit, raiders, kari, tale,
# Nearest to running: manages, synchronize, silverstone, perro, algal, brandt, willem, sneeze,
# Nearest to freedom: vivant, oas, corrupt, rn, sonet, sima, grievous, verbatim,
# Nearest to powers: pseudepigraphical, chiefs, pence, watering, mccormick, hosts, rendered, volunteer,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.4622 0.4648 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.5227 0.4551 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 4.5009 0.4464 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.4734 0.4453 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.3919 0.4436 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.4137 0.4547 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 4.4657 0.4751 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 4.4729 0.5526 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 4.3996 0.5283 sec/batch
# Epoch 1/10 Iteration: 12000 Avg. Training loss: 4.4554 0.4657 sec/batch
# Nearest to was: did, is, eradicated, praetor, rinaldo, subtler, ricardian, integrated,
# Nearest to to: heldenplatz, svalbard, melito, organically, incursions, permanently, nevins, joule,
# Nearest to will: trajectory, chase, pnc, beer, would, pick, menagerie, nightmare,
# Nearest to that: firework, atb, condoleezza, raging, problem, annexation, orchestrations, liberals,
# Nearest to b: qquad, melville, drc, flatly, cockpit, oaks, canisters, detour,
# Nearest to system: detainees, reflecting, chola, connery, repubblica, homogenous, flavours, unlawful,
# Nearest to many: some, ferment, deformed, inhomogeneities, catv, tact, earliest, recognize,
# Nearest to d: fraenkel, subtitled, axiom, parastatal, typhon, favorite, jettison, danville,
# Nearest to event: disturbance, horst, hiv, diminishes, tippi, battalions, sheepdog, quark,
# Nearest to older: protected, harry, airs, underlining, theorist, sewn, arndt, sultans,
# Nearest to magazine: engagements, starbuck, bluebeard, prize, inflating, bioengineering, landowners, apr,
# Nearest to writers: therus, chervil, craggy, bishvat, rhombicuboctahedron, zamora, ina, habib,
# Nearest to smith: speculators, plump, monday, raiders, albeit, bs, kari, tale,
# Nearest to running: manages, synchronize, silverstone, algal, perro, brandt, load, willem,
# Nearest to freedom: vivant, oas, corrupt, rn, sonet, sima, appendix, verbatim,
# Nearest to powers: pseudepigraphical, watering, pence, chiefs, khoikhoi, hosts, volunteer, rendered,
# Epoch 1/10 Iteration: 12100 Avg. Training loss: 4.4695 0.4973 sec/batch
# Epoch 1/10 Iteration: 12200 Avg. Training loss: 4.3980 0.4735 sec/batch
# Epoch 1/10 Iteration: 12300 Avg. Training loss: 4.5033 0.4700 sec/batch
# Epoch 1/10 Iteration: 12400 Avg. Training loss: 4.2965 0.4722 sec/batch
# Epoch 1/10 Iteration: 12500 Avg. Training loss: 4.0295 0.4422 sec/batch
# Epoch 1/10 Iteration: 12600 Avg. Training loss: 4.4224 0.4983 sec/batch
# Epoch 1/10 Iteration: 12700 Avg. Training loss: 4.2913 0.4545 sec/batch
# Epoch 1/10 Iteration: 12800 Avg. Training loss: 4.3169 0.4708 sec/batch
# Epoch 1/10 Iteration: 12900 Avg. Training loss: 4.3900 0.4402 sec/batch
# Epoch 1/10 Iteration: 13000 Avg. Training loss: 4.4280 0.4650 sec/batch
# Nearest to was: is, did, ricardian, spent, became, eradicated, been, rinaldo,
# Nearest to to: heldenplatz, svalbard, melito, did, would, celebrate, nevins, cear,
# Nearest to will: trajectory, chase, would, beer, pnc, can, nightmare, pick,
# Nearest to that: atb, firework, raging, when, condoleezza, annexation, liberals, hissar,
# Nearest to b: melville, drc, oaks, simons, qquad, flatly, masking, cockpit,
# Nearest to system: detainees, reflecting, chola, connery, repubblica, homogenous, sentiments, flavours,
# Nearest to many: some, ferment, deformed, earliest, recognize, inhomogeneities, tact, catv,
# Nearest to d: fraenkel, dramatist, subtitled, typhon, jettison, parastatal, axiom, favorite,
# Nearest to event: disturbance, horst, hiv, diminishes, tippi, battalions, sheepdog, quark,
# Nearest to older: protected, harry, airs, theorist, underlining, sewn, arndt, sultans,
# Nearest to magazine: engagements, bluebeard, starbuck, hollywood, inflating, catalog, hawthorne, katakana,
# Nearest to writers: therus, chervil, bishvat, craggy, habib, skj, gagged, zamora,
# Nearest to smith: speculators, raiders, bs, kari, plump, mma, albeit, monday,
# Nearest to running: manages, synchronize, silverstone, perro, algal, willem, brandt, sneeze,
# Nearest to freedom: vivant, oas, corrupt, rn, sonet, sima, transportable, verbatim,
# Nearest to powers: pseudepigraphical, watering, pence, chiefs, volunteer, khoikhoi, hosts, rendered,
# Epoch 1/10 Iteration: 13100 Avg. Training loss: 4.4436 0.5008 sec/batch
# Epoch 1/10 Iteration: 13200 Avg. Training loss: 4.4943 0.5429 sec/batch
# Epoch 1/10 Iteration: 13300 Avg. Training loss: 4.4389 0.4912 sec/batch
# Epoch 1/10 Iteration: 13400 Avg. Training loss: 4.4900 0.4579 sec/batch
# Epoch 1/10 Iteration: 13500 Avg. Training loss: 4.5100 0.4731 sec/batch
# Epoch 1/10 Iteration: 13600 Avg. Training loss: 4.5151 0.4470 sec/batch
# Epoch 1/10 Iteration: 13700 Avg. Training loss: 4.4849 0.4989 sec/batch
# Epoch 1/10 Iteration: 13800 Avg. Training loss: 4.4656 0.4932 sec/batch
# Epoch 1/10 Iteration: 13900 Avg. Training loss: 4.4212 0.5213 sec/batch
# Epoch 1/10 Iteration: 14000 Avg. Training loss: 4.2852 0.4925 sec/batch
# Nearest to was: is, did, became, eradicated, praetor, rinaldo, spent, fervent,
# Nearest to to: heldenplatz, svalbard, nevins, incursions, melito, appalled, parades, organically,
# Nearest to will: trajectory, chase, would, pnc, can, nightmare, slows, cambodians,
# Nearest to that: firework, raging, atb, annexation, bionic, condoleezza, problem, enslavement,
# Nearest to b: drc, melville, masking, flatly, oaks, cockpit, simons, detour,
# Nearest to system: detainees, reflecting, chola, connery, unlawful, flavours, repubblica, sentiments,
# Nearest to many: some, ferment, catv, deformed, salons, inhomogeneities, most, earliest,
# Nearest to d: fraenkel, subtitled, axiom, dramatist, parastatal, typhon, familial, jettison,
# Nearest to event: disturbance, horst, hiv, diminishes, tippi, sheepdog, quark, battalions,
# Nearest to older: protected, harry, sultans, airs, sewn, theorist, underlining, arndt,
# Nearest to magazine: engagements, bluebeard, starbuck, lot, katakana, catalog, hollywood, inflating,
# Nearest to writers: therus, chervil, craggy, bishvat, skj, gagged, habib, zamora,
# Nearest to smith: speculators, raiders, bs, kari, plump, tale, albeit, mma,
# Nearest to running: manages, silverstone, synchronize, perro, willem, algal, ynys, load,
# Nearest to freedom: vivant, corrupt, oas, rn, sonet, verbatim, transportable, sima,
# Nearest to powers: pseudepigraphical, pence, watering, chiefs, volunteer, hosts, wherever, rendered,
# Epoch 1/10 Iteration: 14100 Avg. Training loss: 4.4634 0.4799 sec/batch
# Epoch 1/10 Iteration: 14200 Avg. Training loss: 4.4820 0.4904 sec/batch
# Epoch 1/10 Iteration: 14300 Avg. Training loss: 4.4505 0.4707 sec/batch
# Epoch 1/10 Iteration: 14400 Avg. Training loss: 4.4697 0.4589 sec/batch
# Epoch 1/10 Iteration: 14500 Avg. Training loss: 4.4726 0.4395 sec/batch
# Epoch 1/10 Iteration: 14600 Avg. Training loss: 4.4881 0.4717 sec/batch
# Epoch 1/10 Iteration: 14700 Avg. Training loss: 4.4992 0.5050 sec/batch
# Epoch 1/10 Iteration: 14800 Avg. Training loss: 4.4451 0.4853 sec/batch
# Epoch 1/10 Iteration: 14900 Avg. Training loss: 4.4768 0.5324 sec/batch
# Epoch 1/10 Iteration: 15000 Avg. Training loss: 4.3689 0.5161 sec/batch
# Nearest to was: is, did, became, eradicated, rinaldo, praetor, fervent, ricardian,
# Nearest to to: nevins, heldenplatz, svalbard, melito, organically, cear, parades, proxies,
# Nearest to will: trajectory, would, chase, can, pnc, nightmare, slows, cambodians,
# Nearest to that: firework, atb, condoleezza, raging, annexation, enslavement, bionic, problem,
# Nearest to b: drc, masking, flatly, melville, canisters, qquad, oaks, cockpit,
# Nearest to system: detainees, reflecting, chola, connery, flavours, unlawful, ce, sentiments,
# Nearest to many: some, ferment, catv, earliest, tact, salons, most, deformed,
# Nearest to d: fraenkel, subtitled, axiom, familial, parastatal, dramatist, favorite, typhon,
# Nearest to event: disturbance, horst, diminishes, hiv, sheepdog, battalions, tippi, quark,
# Nearest to older: protected, harry, sewn, airs, sultans, theorist, underlining, arndt,
# Nearest to magazine: engagements, bluebeard, starbuck, catalog, lot, inflating, katakana, apr,
# Nearest to writers: therus, chervil, bishvat, craggy, skj, habib, zamora, gagged,
# Nearest to smith: speculators, raiders, bs, tale, kari, plump, mma, albeit,
# Nearest to running: manages, silverstone, synchronize, perro, algal, ynys, willem, meantone,
# Nearest to freedom: vivant, corrupt, oas, sonet, rn, verbatim, transportable, grievous,
# Nearest to powers: pseudepigraphical, pence, watering, chiefs, volunteer, hosts, rendered, khoikhoi,
# Epoch 1/10 Iteration: 15100 Avg. Training loss: 4.2413 0.5452 sec/batch
# Epoch 1/10 Iteration: 15200 Avg. Training loss: 4.3635 0.5970 sec/batch
# Epoch 1/10 Iteration: 15300 Avg. Training loss: 4.4473 0.4986 sec/batch
# Epoch 1/10 Iteration: 15400 Avg. Training loss: 4.4377 0.4472 sec/batch
# Epoch 1/10 Iteration: 15500 Avg. Training loss: 4.2841 0.4437 sec/batch
# Epoch 1/10 Iteration: 15600 Avg. Training loss: 4.4396 0.4500 sec/batch
# Epoch 1/10 Iteration: 15700 Avg. Training loss: 4.4285 0.4421 sec/batch
# Epoch 1/10 Iteration: 15800 Avg. Training loss: 4.4471 0.4451 sec/batch
# Epoch 1/10 Iteration: 15900 Avg. Training loss: 4.4679 0.4452 sec/batch
# Epoch 1/10 Iteration: 16000 Avg. Training loss: 4.3429 0.4683 sec/batch
# Nearest to was: is, did, became, eradicated, rinaldo, praetor, been, ricardian,
# Nearest to to: nevins, heldenplatz, parades, melito, organically, cear, svalbard, hogs,
# Nearest to will: trajectory, would, chase, can, nightmare, pnc, slows, cambodians,
# Nearest to that: firework, atb, raging, condoleezza, annexation, bionic, when, arteries,
# Nearest to b: drc, melville, qquad, oaks, simons, dich, masking, detour,
# Nearest to system: detainees, chola, reflecting, connery, flavours, satirizing, homogenous, rod,
# Nearest to many: some, ferment, catv, earliest, salons, most, tact, deformed,
# Nearest to d: fraenkel, subtitled, dramatist, axiom, jettison, typhon, favorite, talbot,
# Nearest to event: disturbance, horst, diminishes, sheepdog, hiv, battalions, tippi, thrives,
# Nearest to older: protected, harry, airs, theorist, sultans, sewn, underlining, arndt,
# Nearest to magazine: engagements, bluebeard, starbuck, lot, catalog, bioengineering, inflating, katakana,
# Nearest to writers: chervil, therus, bishvat, craggy, habib, skj, antecedents, zamora,
# Nearest to smith: speculators, raiders, bs, mma, kari, tale, plump, kuhn,
# Nearest to running: manages, silverstone, synchronize, perro, algal, ynys, willem, load,
# Nearest to freedom: vivant, oas, corrupt, rn, sonet, sima, transportable, appendix,
# Nearest to powers: pseudepigraphical, pence, watering, volunteer, chiefs, hosts, khoikhoi, granary,
# Epoch 1/10 Iteration: 16100 Avg. Training loss: 4.3947 0.5131 sec/batch
# Epoch 1/10 Iteration: 16200 Avg. Training loss: 4.3907 0.4657 sec/batch
# Epoch 1/10 Iteration: 16300 Avg. Training loss: 4.4168 0.4525 sec/batch
# Epoch 1/10 Iteration: 16400 Avg. Training loss: 4.4583 0.4441 sec/batch
# Epoch 1/10 Iteration: 16500 Avg. Training loss: 4.4833 0.4448 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.4375 0.3556 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.4394 0.4428 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.3777 0.4433 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.4342 0.4682 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.4195 0.4422 sec/batch
# Nearest to was: is, did, became, eradicated, fervent, rinaldo, ricardian, been,
# Nearest to to: melito, svalbard, nevins, evolves, hogs, heldenplatz, incursions, organically,
# Nearest to will: trajectory, would, can, chase, pnc, slows, nightmare, could,
# Nearest to that: firework, atb, raging, condoleezza, when, which, annexation, exam,
# Nearest to b: drc, masking, dich, qquad, oaks, melville, flatly, canisters,
# Nearest to system: detainees, chola, reflecting, sentiments, flavours, connery, homogenous, bastia,
# Nearest to many: some, ferment, earliest, catv, most, deformed, salons, these,
# Nearest to d: fraenkel, subtitled, axiom, dramatist, jettison, favorite, familial, ginzburg,
# Nearest to event: disturbance, diminishes, horst, hiv, sheepdog, battalions, tippi, quark,
# Nearest to older: protected, harry, theorist, airs, sultans, sewn, underlining, jihadist,
# Nearest to magazine: engagements, bluebeard, bioengineering, apr, starbuck, catalog, katakana, lot,
# Nearest to writers: chervil, therus, bishvat, craggy, skj, habib, antecedents, gaddis,
# Nearest to smith: speculators, raiders, bs, tale, plump, mma, kari, kuhn,
# Nearest to running: manages, synchronize, silverstone, perro, meantone, cutbacks, load, ynys,
# Nearest to freedom: vivant, corrupt, oas, rn, sonet, transportable, appendix, sima,
# Nearest to powers: pseudepigraphical, pence, watering, volunteer, chiefs, hosts, affirmed, khoikhoi,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.3674 0.5204 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.3794 0.4412 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.3908 0.4449 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.3792 0.4497 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.2920 0.4407 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.3065 0.6667 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.3237 36.4016 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.4275 64.6810 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.4064 0.4928 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.3590 64.8307 sec/batch
# Nearest to was: is, became, did, curl, eradicated, praetor, magyar, fervent,
# Nearest to to: nevins, melito, svalbard, organically, incursions, proxies, heldenplatz, tomcats,
# Nearest to will: would, trajectory, can, chase, pnc, nightmare, slows, could,
# Nearest to that: firework, atb, raging, annexation, condoleezza, which, exam, homininae,
# Nearest to b: drc, melville, dich, masking, pym, qquad, oaks, flatly,
# Nearest to system: detainees, chola, flavours, reflecting, homogenous, connery, unlawful, sentiments,
# Nearest to many: some, ferment, most, earliest, catv, salons, deformed, these,
# Nearest to d: fraenkel, subtitled, dramatist, henley, laureate, jettison, axiom, secures,
# Nearest to event: disturbance, horst, diminishes, quark, sheepdog, hiv, battalions, tippi,
# Nearest to older: protected, harry, theorist, sultans, airs, underlining, sewn, arndt,
# Nearest to magazine: catalog, engagements, bioengineering, katakana, apr, starbuck, bluebeard, inflating,
# Nearest to writers: therus, bishvat, chervil, craggy, habib, skj, authors, zamora,
# Nearest to smith: speculators, raiders, bs, tale, mma, kari, kuhn, plump,
# Nearest to running: manages, synchronize, silverstone, cutbacks, load, meantone, perro, ynys,
# Nearest to freedom: vivant, oas, corrupt, sonet, rn, subordo, transportable, sima,
# Nearest to powers: pence, watering, pseudepigraphical, volunteer, chiefs, khoikhoi, hosts, rendered,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.4041 64.8414 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.3906 64.6486 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.4011 63.4305 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.3831 21.4614 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.4204 0.5191 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.4038 3.2519 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.3995 24.7854 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.4103 0.4950 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.3321 0.4705 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.3350 0.4707 sec/batch
# Nearest to was: is, became, did, remained, praetor, curl, fervent, moyne,
# Nearest to to: nevins, heldenplatz, incursions, svalbard, hoodlum, organically, melito, fertile,
# Nearest to will: would, can, trajectory, chase, slows, nightmare, pnc, could,
# Nearest to that: firework, raging, atb, annexation, condoleezza, which, enslavement, homininae,
# Nearest to b: drc, melville, masking, dich, oaks, canisters, flatly, qquad,
# Nearest to system: detainees, chola, homogenous, reflecting, connery, flavours, satirizing, bastia,
# Nearest to many: some, ferment, catv, most, earliest, these, suggestibility, salons,
# Nearest to d: fraenkel, subtitled, axiom, henley, jettison, dramatist, secures, ginzburg,
# Nearest to event: disturbance, horst, sheepdog, diminishes, battalions, quark, hiv, thrives,
# Nearest to older: protected, harry, sultans, theorist, sewn, airs, underlining, arndt,
# Nearest to magazine: engagements, bioengineering, katakana, catalog, bluebeard, starbuck, apr, lot,
# Nearest to writers: therus, bishvat, habib, skj, chervil, craggy, authors, bangalore,
# Nearest to smith: speculators, raiders, bs, tale, kuhn, mma, kari, plump,
# Nearest to running: manages, synchronize, silverstone, meantone, cutbacks, algal, perro, load,
# Nearest to freedom: oas, corrupt, vivant, sonet, rn, subordo, transportable, sima,
# Nearest to powers: pence, pseudepigraphical, watering, volunteer, chiefs, hosts, khoikhoi, rendered,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.4215 0.4555 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.4093 0.4580 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.4585 0.4447 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.4075 0.4638 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.4286 0.4448 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.3802 0.4419 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.3958 0.4428 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.3701 0.4440 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.4189 0.4422 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.4256 0.4428 sec/batch
# Nearest to was: is, became, did, remained, praetor, fervent, moyne, evander,
# Nearest to to: nevins, incursions, heldenplatz, svalbard, melito, proxies, hoodlum, celebrate,
# Nearest to will: would, can, trajectory, chase, nightmare, could, slows, pnc,
# Nearest to that: firework, raging, which, annexation, condoleezza, atb, exam, mestres,
# Nearest to b: masking, drc, qquad, dich, melville, canisters, flatly, oaks,
# Nearest to system: detainees, chola, flavours, homogenous, connery, reflecting, satirizing, sentiments,
# Nearest to many: some, ferment, earliest, most, these, catv, several, deformed,
# Nearest to d: fraenkel, subtitled, axiom, familial, henley, ginzburg, jettison, parastatal,
# Nearest to event: disturbance, horst, quark, diminishes, sheepdog, battalions, thrives, hiv,
# Nearest to older: protected, harry, theorist, sultans, sewn, airs, underlining, sunga,
# Nearest to magazine: engagements, katakana, bioengineering, bluebeard, catalog, lot, apr, starbuck,
# Nearest to writers: bishvat, therus, craggy, habib, chervil, skj, bangalore, authors,
# Nearest to smith: speculators, raiders, bs, tale, mma, kuhn, kari, albeit,
# Nearest to running: manages, synchronize, silverstone, meantone, algal, perro, load, wasting,
# Nearest to freedom: oas, corrupt, sonet, vivant, rn, transportable, subordo, fractional,
# Nearest to powers: watering, pseudepigraphical, pence, volunteer, chiefs, khoikhoi, hosts, rendered,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.4083 0.4633 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.4085 0.4531 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.3601 0.4448 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.3767 0.4443 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.3637 0.4414 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.2103 0.4452 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.3551 0.5036 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.4149 0.5072 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.3524 0.4697 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.3958 0.5689 sec/batch
# Nearest to was: is, became, did, fervent, remained, moyne, praetor, evander,
# Nearest to to: nevins, melito, svalbard, heldenplatz, incursions, proxies, administratively, stennis,
# Nearest to will: would, can, trajectory, chase, slows, could, pnc, nightmare,
# Nearest to that: which, firework, raging, annexation, condoleezza, when, punks, mythography,
# Nearest to b: drc, masking, qquad, canisters, dich, reinterpretation, nisj, coldcut,
# Nearest to system: detainees, chola, homogenous, connery, unlawful, flavours, sentiments, reflecting,
# Nearest to many: some, ferment, most, several, these, earliest, salons, catv,
# Nearest to d: fraenkel, subtitled, axiom, jettison, familial, henley, secures, ginzburg,
# Nearest to event: disturbance, horst, quark, diminishes, sheepdog, thrives, hiv, tippi,
# Nearest to older: protected, harry, theorist, sultans, airs, sewn, underlining, arndt,
# Nearest to magazine: katakana, engagements, bioengineering, bluebeard, catalog, apr, starbuck, lot,
# Nearest to writers: chervil, bishvat, therus, craggy, habib, skj, authors, bangalore,
# Nearest to smith: speculators, tale, bs, raiders, mma, kuhn, doings, kari,
# Nearest to running: manages, synchronize, silverstone, perro, meantone, algal, wasting, swings,
# Nearest to freedom: oas, corrupt, sonet, vivant, rn, transportable, sima, fractional,
# Nearest to powers: pence, watering, pseudepigraphical, volunteer, chiefs, cathedra, khoikhoi, affirmed,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 4.3744 0.4664 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 4.4011 0.4480 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 4.3826 0.4939 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 4.4003 0.5337 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.3464 0.5259 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 4.4088 0.5241 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.4098 0.5485 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.4139 0.5257 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.3879 0.6339 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.4076 0.5623 sec/batch
# Nearest to was: is, became, did, fervent, remained, praetor, were, moyne,
# Nearest to to: nevins, melito, heldenplatz, organically, hoodlum, svalbard, incursions, tonsils,
# Nearest to will: would, can, trajectory, chase, slows, pnc, could, cambodians,
# Nearest to that: firework, which, raging, when, mythography, annexation, punks, bovidae,
# Nearest to b: drc, masking, qquad, canisters, dich, harkonnen, flatly, quadratic,
# Nearest to system: detainees, chola, flavours, homogenous, reflecting, sentiments, connery, rod,
# Nearest to many: some, ferment, several, most, these, earliest, catv, salons,
# Nearest to d: fraenkel, subtitled, axiom, jettison, familial, henley, asp, carcinogenic,
# Nearest to event: disturbance, horst, diminishes, quark, thrives, sheepdog, tippi, lachish,
# Nearest to older: protected, harry, theorist, airs, sultans, underlining, sewn, arndt,
# Nearest to magazine: katakana, engagements, bioengineering, catalog, apr, bluebeard, hawthorne, starbuck,
# Nearest to writers: chervil, craggy, bishvat, therus, habib, skj, bangalore, authors,
# Nearest to smith: speculators, tale, bs, raiders, mma, kari, kuhn, doings,
# Nearest to running: manages, synchronize, silverstone, meantone, perro, cutbacks, swings, algal,
# Nearest to freedom: corrupt, oas, sonet, vivant, rn, subordo, transportable, fractional,
# Nearest to powers: watering, pseudepigraphical, pence, volunteer, chiefs, affirmed, cathedra, khoikhoi,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 4.3712 0.4563 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 4.3742 108.3620 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 4.3825 37.6460 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 4.4224 0.4919 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 4.4190 0.4656 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 4.3423 0.4803 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 4.3636 0.4467 sec/batch
# Epoch 2/10 Iteration: 22800 Avg. Training loss: 4.3908 0.4439 sec/batch
# Epoch 2/10 Iteration: 22900 Avg. Training loss: 4.3124 0.4894 sec/batch
# Epoch 2/10 Iteration: 23000 Avg. Training loss: 4.3986 0.4972 sec/batch
# Nearest to was: is, became, did, fervent, remained, moyne, ricardian, praetor,
# Nearest to to: nevins, organically, melito, heldenplatz, tonsils, hoodlum, erode, proxies,
# Nearest to will: would, can, trajectory, chase, slows, could, pnc, cambodians,
# Nearest to that: which, firework, raging, when, idle, bovidae, mestres, enslavement,
# Nearest to b: qquad, drc, dich, masking, melville, pym, canisters, flatly,
# Nearest to system: detainees, chola, flavours, homogenous, connery, reflecting, bastia, rod,
# Nearest to many: some, several, ferment, most, these, earliest, sorts, tact,
# Nearest to d: fraenkel, subtitled, henley, axiom, dramatist, jettison, laureate, familial,
# Nearest to event: disturbance, horst, quark, thrives, diminishes, sheepdog, battalions, lachish,
# Nearest to older: protected, harry, theorist, sultans, airs, underlining, sewn, arndt,
# Nearest to magazine: bioengineering, apr, katakana, engagements, catalog, bluebeard, starbuck, observations,
# Nearest to writers: bishvat, chervil, craggy, therus, habib, bangalore, skj, authors,
# Nearest to smith: tale, speculators, bs, raiders, kari, mma, kuhn, plump,
# Nearest to running: manages, synchronize, meantone, silverstone, wasting, perro, linebackers, willem,
# Nearest to freedom: oas, corrupt, sonet, vivant, rn, fractional, transportable, subordo,
# Nearest to powers: pseudepigraphical, pence, watering, volunteer, chiefs, affirmed, khoikhoi, ramirez,
# Epoch 2/10 Iteration: 23100 Avg. Training loss: 4.4121 0.5066 sec/batch
# Epoch 2/10 Iteration: 23200 Avg. Training loss: 4.3927 0.5023 sec/batch
# Epoch 2/10 Iteration: 23300 Avg. Training loss: 4.3718 0.4948 sec/batch
# Epoch 2/10 Iteration: 23400 Avg. Training loss: 4.4059 0.4986 sec/batch
# Epoch 2/10 Iteration: 23500 Avg. Training loss: 4.4121 0.4923 sec/batch
# Epoch 2/10 Iteration: 23600 Avg. Training loss: 4.3740 0.4977 sec/batch
# Epoch 2/10 Iteration: 23700 Avg. Training loss: 4.2905 0.4989 sec/batch
# Epoch 2/10 Iteration: 23800 Avg. Training loss: 4.3868 0.5024 sec/batch
# Epoch 2/10 Iteration: 23900 Avg. Training loss: 4.3644 0.5041 sec/batch
# Epoch 2/10 Iteration: 24000 Avg. Training loss: 4.3387 0.5013 sec/batch
# Nearest to was: is, became, did, remained, moyne, were, fervent, ricardian,
# Nearest to to: nevins, melito, svalbard, organically, administratively, heldenplatz, tonsils, stennis,
# Nearest to will: would, can, trajectory, chase, slows, pnc, could, tend,
# Nearest to that: which, firework, when, raging, enslavement, mestres, annexation, condoleezza,
# Nearest to b: masking, qquad, dich, drc, canisters, flatly, find, melville,
# Nearest to system: detainees, chola, homogenous, flavours, bastia, brahmi, reflecting, connery,
# Nearest to many: some, several, ferment, most, these, earliest, sorts, suggestibility,
# Nearest to d: fraenkel, subtitled, axiom, henley, jettison, familial, ginzburg, secures,
# Nearest to event: disturbance, horst, thrives, quark, diminishes, sheepdog, flurry, excuse,
# Nearest to older: protected, harry, theorist, sultans, underlining, sewn, airs, arndt,
# Nearest to magazine: katakana, engagements, bioengineering, apr, bluebeard, catalog, hawthorne, lot,
# Nearest to writers: chervil, craggy, bishvat, habib, bangalore, therus, skj, authors,
# Nearest to smith: bs, tale, speculators, raiders, kuhn, mma, kari, albeit,
# Nearest to running: manages, synchronize, meantone, silverstone, ynys, algal, linebackers, soir,
# Nearest to freedom: corrupt, oas, vivant, sonet, rn, subordo, transportable, fractional,
# Nearest to powers: watering, pence, pseudepigraphical, volunteer, chiefs, affirmed, ramirez, cathedra,
# Epoch 2/10 Iteration: 24100 Avg. Training loss: 4.3897 0.5060 sec/batch
# Epoch 2/10 Iteration: 24200 Avg. Training loss: 4.3998 0.4962 sec/batch
# Epoch 2/10 Iteration: 24300 Avg. Training loss: 4.3866 0.4905 sec/batch
# Epoch 2/10 Iteration: 24400 Avg. Training loss: 4.3647 0.4917 sec/batch
# Epoch 2/10 Iteration: 24500 Avg. Training loss: 4.4094 0.4895 sec/batch
# Epoch 2/10 Iteration: 24600 Avg. Training loss: 4.3957 0.4862 sec/batch
# Epoch 2/10 Iteration: 24700 Avg. Training loss: 4.3369 0.4942 sec/batch
# Epoch 2/10 Iteration: 24800 Avg. Training loss: 4.3796 0.4882 sec/batch
# Epoch 2/10 Iteration: 24900 Avg. Training loss: 4.3847 44.6513 sec/batch
# Epoch 2/10 Iteration: 25000 Avg. Training loss: 4.3073 76.2795 sec/batch
# Nearest to was: is, became, did, remained, were, fervent, moyne, ricardian,
# Nearest to to: nevins, melito, svalbard, organically, heldenplatz, stennis, incursions, proxies,
# Nearest to will: would, can, trajectory, chase, slows, could, should, pnc,
# Nearest to that: which, firework, raging, when, enslavement, annexation, mestres, idle,
# Nearest to b: qquad, masking, dich, melville, drc, pym, botanist, detour,
# Nearest to system: detainees, chola, homogenous, connery, flavours, reflecting, crusher, topspinner,
# Nearest to many: some, several, most, ferment, these, earliest, sorts, tact,
# Nearest to d: fraenkel, henley, subtitled, dramatist, axiom, laureate, jettison, familial,
# Nearest to event: disturbance, horst, quark, thrives, diminishes, sheepdog, lachish, flurry,
# Nearest to older: protected, harry, sultans, theorist, airs, underlining, sewn, zwolle,
# Nearest to magazine: katakana, engagements, apr, bioengineering, hawthorne, bluebeard, lot, catalog,
# Nearest to writers: authors, craggy, habib, bangalore, bishvat, skj, chervil, therus,
# Nearest to smith: bs, speculators, raiders, tale, kuhn, mma, kari, albeit,
# Nearest to running: manages, synchronize, silverstone, meantone, ynys, algal, wasting, linebackers,
# Nearest to freedom: corrupt, oas, vivant, sonet, rn, fractional, subordo, transportable,
# Nearest to powers: pence, pseudepigraphical, chiefs, watering, volunteer, ramirez, khoikhoi, affirmed,
# Epoch 2/10 Iteration: 25100 Avg. Training loss: 4.3346 53.6853 sec/batch
# Epoch 2/10 Iteration: 25200 Avg. Training loss: 4.3839 141.1702 sec/batch
# Epoch 2/10 Iteration: 25300 Avg. Training loss: 4.2957 0.4640 sec/batch
# Epoch 2/10 Iteration: 25400 Avg. Training loss: 4.4243 0.5406 sec/batch
# Epoch 2/10 Iteration: 25500 Avg. Training loss: 4.3797 0.4651 sec/batch
# Epoch 2/10 Iteration: 25600 Avg. Training loss: 4.3999 0.4432 sec/batch
# Epoch 2/10 Iteration: 25700 Avg. Training loss: 4.3439 0.4930 sec/batch
# Epoch 2/10 Iteration: 25800 Avg. Training loss: 4.3883 0.5405 sec/batch
# Epoch 2/10 Iteration: 25900 Avg. Training loss: 4.2278 0.4552 sec/batch
# Epoch 2/10 Iteration: 26000 Avg. Training loss: 4.4080 0.4466 sec/batch
# Nearest to was: is, became, did, were, remained, praetor, had, moyne,
# Nearest to to: nevins, melito, stennis, svalbard, heldenplatz, organically, hoodlum, administratively,
# Nearest to will: would, can, trajectory, could, chase, should, slows, tend,
# Nearest to that: which, firework, raging, enslavement, annexation, mestres, when, homininae,
# Nearest to b: masking, qquad, drc, dich, quadratic, canisters, flatly, melville,
# Nearest to system: detainees, chola, homogenous, connery, topspinner, crusher, satirizing, reflecting,
# Nearest to many: some, several, most, these, ferment, earliest, suggestibility, sorts,
# Nearest to d: fraenkel, subtitled, axiom, familial, henley, jettison, ginzburg, chooser,
# Nearest to event: disturbance, horst, quark, thrives, diminishes, sheepdog, flurry, lachish,
# Nearest to older: protected, harry, sultans, theorist, underlining, sewn, zwolle, sunga,
# Nearest to magazine: katakana, engagements, bioengineering, lot, apr, starbuck, catalog, daily,
# Nearest to writers: chervil, bishvat, authors, bangalore, craggy, habib, therus, skj,
# Nearest to smith: bs, speculators, raiders, tale, albeit, kuhn, kari, mma,
# Nearest to running: manages, synchronize, silverstone, meantone, ynys, swings, algal, linebackers,
# Nearest to freedom: corrupt, oas, vivant, rn, sonet, fractional, transportable, subordo,
# Nearest to powers: pence, volunteer, pseudepigraphical, watering, chiefs, affirmed, ramirez, khoikhoi,
# Epoch 2/10 Iteration: 26100 Avg. Training loss: 4.3602 0.4564 sec/batch
# Epoch 2/10 Iteration: 26200 Avg. Training loss: 4.4009 0.4952 sec/batch
# --------------------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-14-b1d3869cd0d6> in <module>()
#      18             feed = {inputs: x,
#      19                     labels: np.array(y)[:, None]}
# ---> 20             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      21
#      22             loss += train_loss
#
# /Users/tanke/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/tanke/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# /Users/tanke/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /Users/tanke/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# /Users/tanke/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
